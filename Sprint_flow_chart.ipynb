# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulbahuguna123/Checklist-add-edit-lifecycle-based-upon-sprint-lifecycle/blob/main/Sprint_flow_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Create new Sprint;
if(All prvious sprints are close) {
 Enter Description, Start & End date.
 Selecte Score policy;
 //Task will be linked from profile page.
 // Fill up the checklist for the task. If no checklist is added then one checklist with same description as task will be added.
 
 Link Sprint tasks;
 // Total expected Hrs can not be greater than No of Days except weekends x 6 hrs
 if ( Task Expected Hrs is correct) {
   Sprint will be created;
   Send sprint for approval;
   // manager will approve or inform any modification needed
   if(sprint is approved){
     Add user comments in checklist if any;
     
     Enter the result & outcome of checklists after end of sprint;
     
     
     if (You have worked on some unplanned Tasks){ 
       // Manager will approve or modify Hrs for that task.
       Request Hrs for task;
     }
     // manager will review and approve
     send sprint for closure;
     // You can see your score preview;
     Manager has marked sprint closed;
     
     // Manager can modify few fields
     Manager Updated the "Review Sprint"
     You can see your final score & manager comments
                       }
       else{wait or inform to Manager }
 }
 
 else{ correct the Hrs} 
  }
else{
Close prvious sprints;
}

# %% [markdown]
# ![Screenshot 2023-03-01 at 12.12.54.png](data:image/png;base64,...)
