# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulbahuguna123/Checklist-add-edit-lifecycle-based-upon-sprint-lifecycle/blob/main/Checklist_add_edit_lifecycle_based_upon_sprint_lifecycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
// Add Description, Expected Hrs, Min accwpted criteria for checklist completion.
Create new Task;
// Task can be added from profile page
Add task to Sprint;
//  Select type of result & essential creiteria, In case of Numeric Enter best and worst case in numeric value. Description can not be changed afte this.
Add checklist items;
// You can not edit description
Send Sprint for Approval;
Add result according to type;
switch(Result type) {
  case Boolean:
    Choose complete/not complete;
    break;
  case File:
    Attach file;
    break
  case Numeric:
    Add value between worst case & best case;
    break;
}

Save checklist;
// Once sprint is closed you can edit any variable of checklist before adding checklist task to new sprint & sending for approval.
Send Sprint for closure;
Task details completed

# %% [markdown]
# ![Screenshot 2023-03-01 at 12.19.27.png](data:image/png;base64,...)
